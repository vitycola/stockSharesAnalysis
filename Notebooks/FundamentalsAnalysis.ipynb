# %%
from pyStocks.utils import Utils

# %%
tickers = ["AAPL","MSFT","MMM","IBM"]
Utils.getAllData(tickers)
# Out:
#                        CompanyName   Price       Sector  \
# 0                       Apple Inc.  444.45   Technology
# 1            Microsoft Corporation  212.48   Technology
# 2                       3M Company  158.33  Industrials
# 3  International Business Machines  124.96   Technology
#
#                           Industry      MarketCap  SharesVolume      Beta  \
# 0             Consumer Electronics  1900303876096      49511403  1.226373
# 1          Software—Infrastructure  1607974256640      27820421  0.903846
# 2   Specialty Industrial Machinery    91201093632       2184531  0.957692
# 3  Information Technology Services   111286755328       3651226  1.207142
#
#    DividendRate  DividendYield  PayOutRatio     EPS  CurrentRatio  QuickRatio  \
# 0          3.13         0.0072       0.2373  13.185         1.469       1.312
# 1          2.04         0.0094       0.3455   5.760         2.516       2.330
# ...
