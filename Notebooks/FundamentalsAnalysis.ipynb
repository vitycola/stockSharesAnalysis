# %%
from pyStocks.utils import Utils
from pyStocks.fundamentals import Fundamentals
import pandas as pd

# %%
tickers = ["AAPL","MSFT","MMM","IBM"]
Utils.getAllData(tickers)
# Out:
#                        CompanyName       Sector  \
# 0                       Apple Inc.   Technology
# 1            Microsoft Corporation   Technology
# 2                       3M Company  Industrials
# 3  International Business Machines   Technology
#
#                           Industry   Price      MarketCap  SharesVolume  \
# 0             Consumer Electronics  450.91  1927924416512      52442839
# 1          Software—Infrastructure  208.25  1575963066368      32449574
# 2   Specialty Industrial Machinery  161.44    92992512000       2212294
# 3  Information Technology Services  127.11   113201496064       3866885
#
#        Beta  DividendRate  DividendYield  PayOutRatio     EPS  CurrentRatio  \
# 0  1.226373          3.13         0.0074       0.2373  13.185         1.469
# 1  0.903846          2.04         0.0096       0.3455   5.760         2.516
# 2  0.957692          5.82         0.0371       0.6606   8.813         1.937
# 3  1.207142          6.49         0.0522       0.7358   8.811         1.039
#
#    QuickRatio      ROE        PER   PEG  IncreasingRevenue  \
# 0       1.312  0.69248  34.198710  2.74       4.453500e+10
# 1       2.330  0.40140  36.154514  2.23       4.644400e+10
# 2       1.226  0.48810  18.318394  8.68       2.027000e+09
# 3       0.886  0.40973  14.426286  4.39      -2.772000e+09
#
#    IncreasingNetIncome
# 0         9.569000e+09
# 1         1.879200e+10
# 2        -4.800000e+08
# 3        -2.441000e+09
